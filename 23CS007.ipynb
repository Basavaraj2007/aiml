# %% [markdown]
# <a href="https://colab.research.google.com/github/Basavaraj2007/aiml/blob/main/23CS007.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
from nltk import ngrams
nlp=spacy.load("en_core_web_sm")
doc=nlp("Ai is the simulation of human intelligence.")
bigram=ngrams(doc,2)
print(list(bigram))
# Out:
# [(Ai, is), (is, the), (the, simulation), (simulation, of), (of, human), (human, intelligence), (intelligence, .)]

# %%
import spacy
from nltk import ngrams
nlp=spacy.load("en_core_web_sm")
doc=nlp("Ai is the simulation of human intelligence.")
trigram=ngrams(doc,3)
print(list(trigram))
# Out:
# [(Ai, is, the), (is, the, simulation), (the, simulation, of), (simulation, of, human), (of, human, intelligence), (human, intelligence, .)]
