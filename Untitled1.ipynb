# %% [markdown]
# <a href="https://colab.research.google.com/github/Basavaraj2007/aiml/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df=pd.read_csv('/content/iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
x=df[['sepal_length','sepal_width','petal_length','petal_width']]
y=df[['species']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 122           7.7          2.8           6.7          2.0
# 54            6.5          2.8           4.6          1.5
# 124           6.7          3.3           5.7          2.1
# 4             5.0          3.6           1.4          0.2
# 99            5.7          2.8           4.1          1.3
# ..            ...          ...           ...          ...
# 123           6.3          2.7           4.9          1.8
# 19            5.1          3.8           1.5          0.3
# 30            4.8          3.1           1.6          0.2
# 77            6.7          3.0           5.0          1.7
# 81            5.5          2.4           3.7          1.0
#
# [120 rows x 4 columns]

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 69            5.6          2.5           3.9          1.1
# 147           6.5          3.0           5.2          2.0
# 2             4.7          3.2           1.3          0.2
# 107           7.3          2.9           6.3          1.8
# 25            5.0          3.0           1.6          0.2
# 129           7.2          3.0           5.8          1.6
# 85            6.0          3.4           4.5          1.6
# 94            5.6          2.7           4.2          1.3
# 131           7.9          3.8           6.4          2.0
# 143           6.8          3.2           5.9          2.3
# 116           6.5          3.0           5.5          1.8
# 142           5.8          2.7           5.1          1.9
# 75            6.6          3.0           4.4          1.4
# 35            5.0          3.2           1.2          0.2
# 115           6.4          3.2           5.3          2.3
# 134           6.1          2.6           5.6          1.4
# 145           6.7          3.0           5.2          2.3
# 136           6.3          3.4           5.6          2.4
# 89            5.5          2.5           4.0          1.3
# 144           6.7          3.3           5.7          2.5
# 49            5.0          3.3           1.4          0.2
# 37            4.9          3.1           1.5          0.1
# 20            5.4          3.4           1.7          0.2
# 42            4.4          3.2           1.3          0.2
# 108           6.7          2.5           5.8          1.8
# 83            6.0          2.7           5.1          1.6
# 5             5.4          3.9           1.7          0.4
# 125           7.2          3.2           6.0          1.8
# 40            5.0          3.5           1.3          0.3
# 21            5.1          3.7           1.5          0.4

# %%
y_train
# Out:
#         species
# 122   virginica
# 54   versicolor
# 124   virginica
# 4        setosa
# 99   versicolor
# ..          ...
# 123   virginica
# 19       setosa
# 30       setosa
# 77   versicolor
# 81   versicolor
#
# [120 rows x 1 columns]

# %%
y_test
# Out:
#         species
# 69   versicolor
# 147   virginica
# 2        setosa
# 107   virginica
# 25       setosa
# 129   virginica
# 85   versicolor
# 94   versicolor
# 131   virginica
# 143   virginica
# 116   virginica
# 142   virginica
# 75   versicolor
# 35       setosa
# 115   virginica
# 134   virginica
# 145   virginica
# 136   virginica
# 89   versicolor
# 144   virginica
# 49       setosa
# 37       setosa
# 20       setosa
# 42       setosa
# 108   virginica
# 83   versicolor
# 5        setosa
# 125   virginica
# 40       setosa
# 21       setosa
